# %% [markdown]
# <a href="https://colab.research.google.com/github/brahma1995/emotion_analysis/blob/main/sentiment_analysis_emotion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu117, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install transformers requests beautifulsoup4 pandas numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import requests
from bs4 import BeautifulSoup
import re

# %%
tokenizer = AutoTokenizer.from_pretrained('j-hartmann/emotion-english-distilroberta-base')

model = AutoModelForSequenceClassification.from_pretrained('j-hartmann/emotion-english-distilroberta-base')

# %%
tokens = tokenizer.encode("wow how did it happen",return_tensors='pt')

# %%
result = model(tokens)

# %%
result.logits
# Out:
# tensor([[-0.3356, -1.3162, -0.8405, -1.1993,  0.0648, -0.9098,  5.1367]],
#        grad_fn=<AddmmBackward0>)

# %%
int(torch.argmax(result.logits))+1
labels = {"0": "anger",
    "1": "disgust",
    "2": "fear",
    "3": "joy",
    "4": "neutral",
    "5": "sadness",
    "6": "surprise"}
label = torch.argmax(result.logits, axis=1)
label = label.numpy()
print(label)
print(labels[str(label[0])])
# Out:
# [6]
# surprise
